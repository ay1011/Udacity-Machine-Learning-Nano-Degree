# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception('Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary


data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5240, 3083, 12, 6, 195, 2, 3135, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
        
    for i in range(batch_size // num_skips):
        target           = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[ i * num_skips + j]    = buffer[skip_window]  # one-to-many 
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'anarchism', 'originated', 'term', 'term', 'originated', 'of', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
#################
### skip-gram ###
#################
"""predicting the context given a word"""
batch_size     = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window    = 1   # How many words to consider left and right.
num_skips      = 2   # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size     = 16  # Random set of words to evaluate similarity on.
valid_window   = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled    = 64  # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(): #, tf.device('/cpu:0')

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels  = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Variables.
    embeddings      = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size],stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases  = tf.Variable(tf.zeros([vocabulary_size]))

    # Model. 
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm                  = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings      = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity            = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(batch_size, num_skips, skip_window)
        feed_dict                = {train_dataset : batch_data, train_labels : batch_labels}
        _, l                     = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k      = 8 # number of nearest neighbors
                nearest    = (-sim[i, :]).argsort()[1:top_k+1]
                log        = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log        = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.901213
# Nearest to three: avalokitesvara, mci, symposium, kordofanian, millay, radiotherapy, powell, respectful,
# Nearest to eight: schroeder, baralong, laney, intervals, whirlpool, fellows, nebulous, steadfast,
# Nearest to such: ribs, educate, recurring, appearances, ills, schlesinger, bricks, stasi,
# Nearest to had: characterizations, coils, crone, trasimene, periods, elixir, convention, csx,
# Nearest to however: spraying, bd, barrier, quantitative, methods, kandahar, daleks, lyapunov,
# Nearest to it: middletown, exponentials, golda, partners, diplomat, depicting, cultured, reno,
# Nearest to nine: levin, hepatic, papers, louisiana, investigating, ouest, minotaurs, arched,
# Nearest to when: gasses, conceives, needy, trichechus, rebuked, obscura, pizzicato, achaeans,
# Nearest to four: legislator, thermodynamic, gianni, maharashtri, acct, characterizations, advancement, superb,
# Nearest to its: sociolinguistics, monophysite, calder, knows, vh, optional, diskette, bm,
# Nearest to see: hypatia, alchemical, livelihood, collective, raions, cervical, diaeresis, rumored,
# Nearest to american: loewe, ankles, devise, censure, zn, preachers, excesses, koffice,
# Nearest to no: orientation, jihad, qi, bootp, antique, columbine, formalized, heretofore,
# Nearest to with: energized, insertion, trammell, vaccinium, outwardly, gentoo, chapultepec, contemporaries,
# Nearest to new: distract, folder, disconnect, demeaning, britain, med, inspire, witnessed,
# Nearest to as: shenandoah, equals, parsley, warthog, juventus, chronos, disenchanted, averse,
# Average loss at step 2000: 4.356367
# Average loss at step 4000: 3.864354
# Average loss at step 6000: 3.781533
# Average loss at step 8000: 3.687444
# Average loss at step 10000: 3.616142
# Nearest to three: five, four, eight, six, two, seven, nine, zero,
# Nearest to eight: six, nine, five, four, seven, three, zero, two,
# Nearest to such: well, mitral, assorted, consensus, twenties, being, educate, schlesinger,
# Nearest to had: has, have, was, crone, characterizations, coils, resist, gave,
# Nearest to however: bd, anything, tensor, pragmatism, barrier, stagnated, quantitative, methods,
# Nearest to it: he, this, which, they, not, there, also, that,
# Nearest to nine: eight, five, seven, six, three, four, zero, two,
# Nearest to when: gasses, medici, adversus, astronauts, winter, finished, needy, fits,
# Nearest to four: six, seven, three, eight, five, two, nine, zero,
# Nearest to its: the, his, their, cms, documenting, calder, optional, rotary,
# Nearest to see: sortavala, dw, can, fez, jake, binitarianism, glick, speyer,
# Nearest to american: d, antagonism, oswego, ankles, franchise, macmillan, carnival, and,
# Nearest to no: a, it, orientation, qibla, sq, qi, pew, sidekick,
# Nearest to with: for, codename, in, against, by, bowden, dismissing, radical,
# Nearest to new: discourses, chilli, geralt, disconnect, terminate, piccard, demeaning, arenas,
# Nearest to as: be, forgo, among, chronos, salina, vidkun, with, blica,
# Average loss at step 12000: 3.605861
# Average loss at step 14000: 3.569090
# Average loss at step 16000: 3.411209
# Average loss at step 18000: 3.458594
# Average loss at step 20000: 3.538583
# Nearest to three: four, five, six, seven, two, eight, nine, zero,
# Nearest to eight: seven, nine, six, four, five, three, zero, two,
# Nearest to such: well, heapsort, including, twenties, known, mitral, assorted, many,
# Nearest to had: has, have, was, were, having, gave, been, resist,
# Nearest to however: but, there, anything, when, pragmatism, hrvatska, bd, where,
# Nearest to it: he, this, there, they, which, she, not, alle,
# Nearest to nine: eight, six, seven, four, five, three, zero, two,
# Nearest to when: if, after, however, finished, with, took, since, astronauts,
# Nearest to four: six, seven, eight, three, five, nine, two, zero,
# Nearest to its: their, his, the, cms, some, necessity, her, repressing,
# Nearest to see: sortavala, can, eschatological, dw, glick, jake, lott, flip,
# Nearest to american: german, dutch, ankles, esther, cz, antagonism, canadian, french,
# Nearest to no: a, antique, materials, judging, orientation, milky, detroit, flow,
# Nearest to with: in, by, between, for, at, against, bowden, when,
# Nearest to new: discourses, disconnect, piccard, bliss, arenas, subgenius, solitary, federal,
# Nearest to as: clearly, whitney, korn, forgo, mocked, atlantis, hitomaro, enriched,
# Average loss at step 22000: 3.501833
# Average loss at step 24000: 3.494020
# Average loss at step 26000: 3.483964
# Average loss at step 28000: 3.482600
# Average loss at step 30000: 3.502069
# Nearest to three: four, five, two, seven, six, eight, nine, zero,
# Nearest to eight: nine, seven, six, five, four, three, zero, one,
# Nearest to such: well, including, heapsort, these, known, leiber, many, consensus,
# Nearest to had: has, have, was, were, having, sparked, is, when,
# Nearest to however: but, when, although, pragmatism, there, bd, disdain, if,
# Nearest to it: he, there, this, they, she, which, also, still,
# Nearest to nine: eight, seven, six, four, five, three, zero, one,
# Nearest to when: if, however, while, where, before, but, since, after,
# Nearest to four: five, six, seven, eight, three, two, nine, zero,
# Nearest to its: their, his, the, her, repressing, darpa, cms, afghanistan,
# Nearest to see: sortavala, can, azeglio, estis, bfi, dw, have, glick,
# Nearest to american: english, german, dutch, canadian, dramatist, and, potsdamer, scottish,
# Nearest to no: a, materials, orientation, antique, it, judging, milky, riders,
# Nearest to with: between, codename, when, bowden, vaccinium, without, by, against,
# Nearest to new: particular, geralt, discourses, original, single, arenas, macintosh, sowell,
# Nearest to as: whitney, clearly, widely, by, chronos, when, vouchers, decisively,
# Average loss at step 32000: 3.501325
# Average loss at step 34000: 3.492607
# Average loss at step 36000: 3.452822
# Average loss at step 38000: 3.296438
# Average loss at step 40000: 3.427861
# Nearest to three: five, two, four, seven, six, eight, nine, one,
# Nearest to eight: nine, seven, six, four, five, three, zero, one,
# Nearest to such: well, including, these, known, heapsort, leiber, many, dioxin,
# Nearest to had: has, have, was, were, having, been, sparked, bloodlines,
# Nearest to however: but, though, when, although, disdain, that, pragmatism, might,
# Nearest to it: he, there, she, this, they, which, what, that,
# Nearest to nine: eight, seven, six, five, four, zero, three, one,
# Nearest to when: if, while, where, before, but, however, after, although,
# Nearest to four: six, five, eight, seven, three, two, nine, one,
# Nearest to its: their, his, her, the, gloucestershire, gaborone, interconnected, beverly,
# Nearest to see: can, list, but, vespucci, have, include, mainline, sortavala,
# Nearest to american: german, canadian, dutch, french, australian, ankles, international, dramatist,
# Nearest to no: any, materials, a, orientation, saronic, antique, often, than,
# Nearest to with: between, by, when, erne, hw, everest, on, in,
# Nearest to new: discourses, particular, arenas, disconnect, geralt, philippines, khoikhoi, convergence,
# Nearest to as: by, bai, vouchers, clearly, ardent, decisively, domed, bei,
# Average loss at step 42000: 3.437848
# Average loss at step 44000: 3.450480
# Average loss at step 46000: 3.450341
# Average loss at step 48000: 3.352365
# Average loss at step 50000: 3.381435
# Nearest to three: four, six, seven, eight, five, two, nine, zero,
# Nearest to eight: six, seven, nine, four, five, three, zero, two,
# Nearest to such: well, known, these, including, many, heapsort, lucie, some,
# Nearest to had: has, have, was, having, were, esa, recently, josef,
# Nearest to however: but, although, while, though, when, that, where, disdain,
# Nearest to it: he, there, she, this, they, possible, larwood, still,
# Nearest to nine: eight, seven, six, four, five, three, zero, one,
# Nearest to when: if, while, before, where, after, however, but, until,
# Nearest to four: five, six, eight, seven, three, nine, two, zero,
# Nearest to its: their, his, the, her, beverly, rotary, gaborone, interconnected,
# Nearest to see: mainline, list, include, vespucci, can, nested, includes, undergo,
# Nearest to american: german, french, canadian, international, australian, dutch, dramatist, ankles,
# Nearest to no: any, a, questionable, saronic, materials, orientation, little, sakai,
# Nearest to with: between, by, vaccinium, hw, when, erne, liners, bowden,
# Nearest to new: particular, discourses, arenas, sowell, philippines, papandreou, disconnect, engulfed,
# Nearest to as: niki, dvorak, became, rainey, vulgar, decisively, by, tenji,
# Average loss at step 52000: 3.435369
# Average loss at step 54000: 3.423579
# Average loss at step 56000: 3.441522
# Average loss at step 58000: 3.393671
# Average loss at step 60000: 3.390379
# Nearest to three: five, four, seven, eight, six, two, nine, one,
# Nearest to eight: nine, six, seven, four, five, three, zero, two,
# Nearest to such: well, many, these, known, including, some, heapsort, dioxin,
# Nearest to had: has, have, was, were, having, could, been, esa,
# Nearest to however: but, although, though, when, that, which, while, since,
# Nearest to it: he, there, this, she, what, that, which, they,
# Nearest to nine: eight, six, seven, four, five, three, zero, one,
# Nearest to when: if, while, before, after, although, where, though, however,
# Nearest to four: five, six, eight, seven, three, nine, two, zero,
# Nearest to its: their, his, the, her, repressing, blaine, beverly, interconnected,
# Nearest to see: list, but, include, can, mainline, nested, refer, unbelievers,
# Nearest to american: international, australian, british, canadian, german, subgenus, english, french,
# Nearest to no: any, little, orientation, a, questionable, materials, sakai, antique,
# Nearest to with: between, bowden, erne, codename, everest, including, when, in,
# Nearest to new: particular, discourses, macintosh, philippines, major, papandreou, piccard, disconnect,
# Nearest to as: clearly, using, vulgar, shtml, hitomaro, habakkuk, ims, dvorak,
# Average loss at step 62000: 3.236341
# Average loss at step 64000: 3.257421
# Average loss at step 66000: 3.405151
# Average loss at step 68000: 3.390903
# Average loss at step 70000: 3.357621
# Nearest to three: four, six, five, two, seven, eight, nine, one,
# Nearest to eight: nine, six, seven, four, five, zero, three, one,
# Nearest to such: these, well, many, known, heapsort, leiber, serve, lucie,
# Nearest to had: has, have, was, were, having, been, josef, esa,
# Nearest to however: but, although, though, when, that, while, where, if,
# Nearest to it: he, there, she, this, they, still, now, arnauld,
# Nearest to nine: eight, six, seven, five, four, three, zero, one,
# Nearest to when: if, while, before, however, where, although, though, because,
# Nearest to four: six, five, three, eight, seven, nine, two, zero,
# Nearest to its: their, his, the, her, repressing, kazan, your, beverly,
# Nearest to see: list, mainline, and, references, include, but, can, xxxvii,
# Nearest to american: international, australian, british, subgenus, canadian, african, dramatist, stara,
# Nearest to no: any, little, there, materials, orientation, questionable, terrified, traditionally,
# Nearest to with: between, bowden, liners, benitez, dismissing, erne, enhance, suck,
# Nearest to new: philippines, piccard, particular, disconnect, discourses, boost, sowell, khoikhoi,
# Nearest to as: vouchers, atlantis, dvorak, vulgar, trotskyist, numeric, monists, hitomaro,
# Average loss at step 72000: 3.371731
# Average loss at step 74000: 3.352455
# Average loss at step 76000: 3.312194
# Average loss at step 78000: 3.347816
# Average loss at step 80000: 3.377846
# Nearest to three: four, six, five, two, seven, eight, nine, zero,
# Nearest to eight: nine, six, seven, four, five, three, zero, one,
# Nearest to such: well, these, serve, known, including, leiber, dioxin, certain,
# Nearest to had: have, has, were, having, was, josef, esa, been,
# Nearest to however: but, although, though, when, while, that, where, including,
# Nearest to it: he, she, there, this, they, arnauld, which, itself,
# Nearest to nine: eight, seven, six, five, four, three, zero, one,
# Nearest to when: if, before, while, after, although, though, however, where,
# Nearest to four: six, five, three, eight, seven, two, nine, zero,
# Nearest to its: their, his, her, the, your, repressing, jovi, beverly,
# Nearest to see: refer, mainline, but, references, list, undergo, excommunicate, reactance,
# Nearest to american: international, british, subgenus, australian, german, canadian, english, jamestown,
# Nearest to no: little, any, terrified, positives, webelements, polyethylene, earnest, sakai,
# Nearest to with: between, bowden, codename, erne, liners, rechargeable, benitez, enhance,
# Nearest to new: philippines, disconnect, piccard, discourses, papandreou, haikai, arenas, particular,
# Nearest to as: dvorak, shtml, hitomaro, monists, whereas, moravians, hewson, minneapolis,
# Average loss at step 82000: 3.406275
# Average loss at step 84000: 3.410069
# Average loss at step 86000: 3.390874
# Average loss at step 88000: 3.352104
# Average loss at step 90000: 3.362714
# Nearest to three: two, four, five, seven, eight, six, nine, zero,
# Nearest to eight: seven, six, nine, five, four, three, zero, two,
# Nearest to such: well, known, these, lucie, serve, seen, heapsort, certain,
# Nearest to had: has, have, was, were, having, never, josef, would,
# Nearest to however: but, although, though, that, while, when, during, if,
# Nearest to it: he, she, there, this, they, itself, testifies, arnauld,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to when: if, before, while, after, although, where, until, though,
# Nearest to four: five, seven, six, three, eight, two, nine, zero,
# Nearest to its: their, his, her, the, your, our, interconnected, jovi,
# Nearest to see: list, references, includes, refer, history, excommunicate, mainline, but,
# Nearest to american: british, african, australian, international, jamestown, canadian, english, french,
# Nearest to no: any, little, materials, questionable, terrified, rarely, webelements, pillaging,
# Nearest to with: between, bowden, against, liners, erne, rechargeable, hw, by,
# Nearest to new: philippines, arenas, papandreou, disconnect, particular, grizzly, piccard, subgenius,
# Nearest to as: faxes, chinook, habakkuk, dinger, monists, whereas, niki, including,
# Average loss at step 92000: 3.394662
# Average loss at step 94000: 3.248219
# Average loss at step 96000: 3.357661
# Average loss at step 98000: 3.240870
# Average loss at step 100000: 3.356943
# Nearest to three: four, six, five, eight, two, seven, nine, zero,
# Nearest to eight: seven, nine, six, four, five, three, zero, two,
# Nearest to such: well, known, serve, lucie, heapsort, these, many, monotheist,
# Nearest to had: has, have, was, having, were, josef, since, esa,
# Nearest to however: but, although, though, that, where, while, and, when,
# Nearest to it: he, she, this, there, they, nothing, testifies, arnauld,
# Nearest to nine: eight, seven, six, four, five, zero, three, one,
# Nearest to when: if, while, before, although, after, where, though, because,
# Nearest to four: six, seven, five, eight, nine, three, zero, two,
# Nearest to its: their, his, her, the, repressing, our, beverly, gaborone,
# Nearest to see: list, references, refer, includes, excommunicate, stupid, history, mainline,
# Nearest to american: british, canadian, australian, international, wasps, italian, french, english,
# Nearest to no: little, any, there, questionable, orientation, materials, traditionally, judging,
# Nearest to with: between, erne, bowden, including, liners, aum, sahib, hw,
# Nearest to new: philippines, arenas, separate, subgenius, papandreou, sash, nd, telstra,
# Nearest to as: embarking, vulgar, when, thereafter, reg, rainey, continually, hitomaro,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                       ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
######################################
### CBOW (Continuous Bag of Words) ###
######################################
"""predicting the word given its context"""
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
        
    for i in range(batch_size // num_skips):
        target           = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            ############################################################################
            #####################            changes               #####################
            ############################################################################
            batch[ i * num_skips + j]    = buffer[target]                  # many-to-one 
            labels[i * num_skips + j, 0] = buffer[skip_window]
            ############################################################################
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels


batch_size = 16
print('data:', [reverse_dictionary[di] for di in data[:batch_size]])

for num_skips, skip_window in [(2, 1), (4, 2), (8, 4)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=batch_size, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(batch_size)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'a', 'of', 'abuse', 'term', 'of', 'first', 'used', 'abuse', 'against', 'first']
#     labels: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term', 'of', 'of', 'abuse', 'abuse', 'first', 'first', 'used', 'used']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['a', 'originated', 'anarchism', 'term', 'as', 'of', 'originated', 'term', 'abuse', 'a', 'as', 'of', 'first', 'a', 'abuse', 'term']
#     labels: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a', 'term', 'term', 'term', 'term', 'of', 'of', 'of', 'of']
#
# with num_skips = 8 and skip_window = 4:
#     batch: ['used', 'as', 'a', 'anarchism', 'abuse', 'first', 'originated', 'of', 'term', 'abuse', 'against', 'a', 'originated', 'first', 'used', 'as']
#     labels: ['term', 'term', 'term', 'term', 'term', 'term', 'term', 'term', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of']

# %%
######################################
### CBOW (Continuous Bag of Words) ###
######################################
batch_size     = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window    = 1 # How many words to consider left and right.
num_skips      = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size     = 16 # Random set of words to evaluate similarity on.
valid_window   = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled    = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(): #, tf.device('/cpu:0')

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels  = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Variables.
    embeddings      = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size],stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases  = tf.Variable(tf.zeros([vocabulary_size]))

    # Model. 
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm                  = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings      = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity            = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
######################################
### CBOW (Continuous Bag of Words) ###
######################################
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(batch_size, num_skips, skip_window)
        feed_dict                = {train_dataset : batch_data, train_labels : batch_labels}
        _, l                     = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k      = 8 # number of nearest neighbors
                nearest    = (-sim[i, :]).argsort()[1:top_k+1]
                log        = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log        = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.027495
# Nearest to of: ethically, suitor, glut, avesta, acronym, maleficarum, initialized, cooley,
# Nearest to new: sorcery, chances, xiaoping, aelian, mapping, yup, pharaohs, piezoelectric,
# Nearest to this: loaf, published, clippers, fabulous, fortuna, cynic, simulate, pikes,
# Nearest to called: petit, subgenres, horseback, pathogen, slavery, kao, alexey, ingest,
# Nearest to during: cuneiform, validated, steed, dollar, sncf, tolls, plum, essen,
# Nearest to is: cloudbusting, grapevines, bequeathed, pap, broadcasts, brooms, maroon, elaborated,
# Nearest to or: lightly, dissected, rai, roof, compartments, dirty, rtf, refinery,
# Nearest to over: dactyl, grille, storylines, ade, gaddis, participating, doppelbock, subsurface,
# Nearest to four: burner, capitalists, interactively, pete, cara, disenchanted, purging, planetarium,
# Nearest to he: avoidance, unionists, pistols, pekah, zimmer, ioannes, cam, cast,
# Nearest to not: pigment, hegelians, unalaska, healed, abdicating, clifton, shapur, subversion,
# Nearest to d: andersonville, straightening, thames, reds, trianon, possessors, doorway, fruits,
# Nearest to most: pharisees, emulsifiers, initially, brisingamen, pose, annual, puppies, piece,
# Nearest to often: merchants, montreal, globalization, entail, meditations, superscription, chopping, ambivalent,
# Nearest to the: racers, coalesced, professionally, marischal, christianity, all, illuminating, seleucus,
# Nearest to by: southwestern, tzow, repertoire, thriving, preferred, automatically, sinclair, distract,
# Average loss at step 2000: 4.359302
# Average loss at step 4000: 3.866136
# Average loss at step 6000: 3.790001
# Average loss at step 8000: 3.691381
# Average loss at step 10000: 3.615650
# Nearest to of: in, for, at, and, avesta, spence, reopen, practitioners,
# Nearest to new: vowels, watterson, topmost, sorcery, skeptics, hundred, pharaohs, teddy,
# Nearest to this: it, the, which, customer, that, their, simulate, a,
# Nearest to called: jeffreys, kao, advertise, chairs, recount, caleb, petit, subgenres,
# Nearest to during: steed, derby, in, ashikaga, cuneiform, browns, exploration, breakaway,
# Nearest to is: was, are, has, does, vre, handicraft, deontology, be,
# Nearest to or: and, refinery, pioneering, loma, gratis, but, proficient, every,
# Nearest to over: dactyl, socializing, without, archers, christy, nontrinitarian, grille, ntsc,
# Nearest to four: eight, six, three, five, seven, two, nine, zero,
# Nearest to he: it, they, she, who, informatics, cast, esther, irreversibly,
# Nearest to not: it, we, also, minotaur, laoghaire, who, they, converge,
# Nearest to d: b, andersonville, straightening, bunsen, thames, lomax, fruits, engels,
# Nearest to most: all, passively, initially, riverside, discus, bandai, protester, brisingamen,
# Nearest to often: also, mua, repeater, superscription, ambivalent, montreal, attendant, synapomorphies,
# Nearest to the: a, this, its, ryu, his, an, ramjet, their,
# Nearest to by: was, with, after, caustic, scheldt, against, yahoo, plow,
# Average loss at step 12000: 3.604205
# Average loss at step 14000: 3.568878
# Average loss at step 16000: 3.411745
# Average loss at step 18000: 3.459016
# Average loss at step 20000: 3.536992
# Nearest to of: for, sima, categorised, and, in, original, scala, unaided,
# Nearest to new: vowels, historical, watterson, symbolist, sorcery, militare, teddy, conforming,
# Nearest to this: it, which, his, customer, the, their, a, any,
# Nearest to called: advertise, jeffreys, kao, held, picks, petit, caleb, linux,
# Nearest to during: in, after, throughout, over, from, steed, breakaway, nouakchott,
# Nearest to is: was, are, has, be, does, but, if, joint,
# Nearest to or: and, than, galilei, rationalisation, pioneering, banners, with, lett,
# Nearest to over: during, dactyl, nontrinitarian, socializing, without, archers, seeker, healthy,
# Nearest to four: three, seven, eight, five, six, two, nine, zero,
# Nearest to he: it, she, they, who, informatics, there, stony, later,
# Nearest to not: also, they, it, converge, who, to, generally, still,
# Nearest to d: b, bunsen, particularity, loud, motorised, marina, exclusivity, fruits,
# Nearest to most: more, many, initially, tydings, protester, brisingamen, sound, bandai,
# Nearest to often: also, repeater, usually, mua, still, which, akron, superscription,
# Nearest to the: its, their, his, witches, this, some, an, a,
# Nearest to by: scheldt, caustic, be, with, under, were, after, mebyon,
# Average loss at step 22000: 3.504221
# Average loss at step 24000: 3.492616
# Average loss at step 26000: 3.479740
# Average loss at step 28000: 3.479886
# Average loss at step 30000: 3.499329
# Nearest to of: in, from, and, for, mints, dysplasia, sima, initial,
# Nearest to new: conforming, militare, watterson, yersinia, symbolist, arbitration, teddy, historical,
# Nearest to this: it, which, that, customer, homographs, harpsichords, what, any,
# Nearest to called: used, jeffreys, advertise, linux, pathogen, held, handball, excommunicate,
# Nearest to during: after, in, throughout, from, over, on, nouakchott, breakaway,
# Nearest to is: was, has, are, be, does, became, but, macphail,
# Nearest to or: and, than, ns, pioneering, cortes, refugee, as, westernized,
# Nearest to over: during, dactyl, years, healthy, without, before, modernized, uml,
# Nearest to four: five, eight, six, three, seven, two, nine, zero,
# Nearest to he: she, it, they, who, there, informatics, copernican, never,
# Nearest to not: they, it, generally, still, piero, converge, less, machines,
# Nearest to d: b, loud, sarah, thames, mannerist, guarantee, andersonville, kimchi,
# Nearest to most: more, many, protester, initially, rhotic, bandai, rickey, varicella,
# Nearest to often: usually, still, also, sometimes, commonly, frequently, mua, there,
# Nearest to the: their, its, his, cavour, this, many, some, gail,
# Nearest to by: under, as, in, towards, with, during, were, was,
# Average loss at step 32000: 3.500991
# Average loss at step 34000: 3.493265
# Average loss at step 36000: 3.459359
# Average loss at step 38000: 3.294597
# Average loss at step 40000: 3.430130
# Nearest to of: in, kon, original, sima, etruscan, from, for, denning,
# Nearest to new: baraka, arbitration, militare, figs, beneath, teddy, watterson, retroflex,
# Nearest to this: which, it, the, that, a, harpsichords, any, another,
# Nearest to called: handball, advertise, jeffreys, used, pathogen, perl, tempering, considered,
# Nearest to during: after, throughout, in, at, until, nouakchott, exploration, from,
# Nearest to is: was, are, has, does, nokia, be, handicraft, became,
# Nearest to or: and, than, no, a, pioneering, tiglath, oaths, flurry,
# Nearest to over: displacements, dactyl, without, during, years, demarcation, within, megabit,
# Nearest to four: six, three, five, eight, two, seven, one, nine,
# Nearest to he: she, it, they, who, there, informatics, outburst, i,
# Nearest to not: it, generally, still, they, less, also, usually, often,
# Nearest to d: b, UNK, n, loud, thames, andersonville, sarah, kimchi,
# Nearest to most: more, many, celibate, among, pointless, riverside, troubling, malfunction,
# Nearest to often: usually, also, commonly, frequently, sometimes, generally, still, there,
# Nearest to the: a, this, his, any, its, their, another, moncton,
# Nearest to by: with, towards, as, from, caustic, retail, after, was,
# Average loss at step 42000: 3.440400
# Average loss at step 44000: 3.458064
# Average loss at step 46000: 3.452502
# Average loss at step 48000: 3.350293
# Average loss at step 50000: 3.388098
# Nearest to of: in, and, from, unaided, categorised, unlike, for, scone,
# Nearest to new: second, baraka, militare, great, watterson, nasals, drogheda, arbitration,
# Nearest to this: which, it, the, there, what, withdrawing, boziz, deleuze,
# Nearest to called: advertise, handball, perl, used, named, retorted, known, jeffreys,
# Nearest to during: after, in, throughout, from, at, by, before, nouakchott,
# Nearest to is: was, has, are, although, be, macphail, became, indentations,
# Nearest to or: and, than, energetic, like, comptroller, kwakiutl, calhoun, dion,
# Nearest to over: megabit, displacements, without, dumb, dactyl, on, during, under,
# Nearest to four: five, six, three, seven, eight, two, nine, one,
# Nearest to he: she, it, they, who, there, never, informatics, i,
# Nearest to not: generally, still, they, less, considered, usually, piero, who,
# Nearest to d: b, n, f, c, p, dc, m, loud,
# Nearest to most: more, many, less, anchored, some, among, rhotic, faster,
# Nearest to often: usually, generally, sometimes, commonly, also, frequently, typically, still,
# Nearest to the: its, their, this, his, a, some, worsen, another,
# Nearest to by: under, through, caustic, against, towards, during, pluralistic, scheldt,
# Average loss at step 52000: 3.436630
# Average loss at step 54000: 3.426256
# Average loss at step 56000: 3.439353
# Average loss at step 58000: 3.399582
# Average loss at step 60000: 3.394790
# Nearest to of: in, for, streetcars, sima, ramgoolam, original, including, initial,
# Nearest to new: drang, arbitration, watterson, teddy, figs, militare, icing, harpers,
# Nearest to this: it, which, that, there, abducted, serpentine, a, toyota,
# Nearest to called: handball, used, pathogen, named, known, jeffreys, advertise, see,
# Nearest to during: after, throughout, in, before, within, until, despite, at,
# Nearest to is: was, are, be, has, sidebar, does, indicates, became,
# Nearest to or: and, than, pioneering, like, comptroller, tess, include, schroeder,
# Nearest to over: through, palestinian, dactyl, consecutive, without, megabit, during, under,
# Nearest to four: five, six, eight, three, seven, nine, two, zero,
# Nearest to he: she, it, they, who, there, never, informatics, eventually,
# Nearest to not: still, generally, now, piero, they, usually, converge, who,
# Nearest to d: b, n, m, dc, moose, leffler, p, c,
# Nearest to most: many, more, some, among, less, especially, rhotic, hendrik,
# Nearest to often: usually, sometimes, commonly, frequently, generally, also, now, typically,
# Nearest to the: its, their, a, copa, fooled, each, his, blubber,
# Nearest to by: through, be, with, xx, scheldt, abstracted, whither, towards,
# Average loss at step 62000: 3.240218
# Average loss at step 64000: 3.251004
# Average loss at step 66000: 3.403903
# Average loss at step 68000: 3.395560
# Average loss at step 70000: 3.357550
# Nearest to of: sima, including, and, include, or, without, initial, redacted,
# Nearest to new: arbitration, specialist, yersinia, symbolist, drang, medical, aramaean, syria,
# Nearest to this: which, it, the, that, some, another, what, there,
# Nearest to called: named, handball, used, known, perl, retorted, jiva, referred,
# Nearest to during: after, throughout, in, before, until, within, from, retainers,
# Nearest to is: was, has, be, are, twitch, becomes, became, farad,
# Nearest to or: and, pioneering, than, any, kao, kafka, jeanne, immunization,
# Nearest to over: dactyl, palestinian, about, normalized, before, under, darcy, infocom,
# Nearest to four: six, three, five, seven, eight, two, nine, zero,
# Nearest to he: she, it, they, who, there, never, informatics, eventually,
# Nearest to not: still, generally, now, piero, usually, clearly, also, sixties,
# Nearest to d: b, n, dc, f, p, h, moose, m,
# Nearest to most: more, many, less, some, especially, all, several, duns,
# Nearest to often: usually, sometimes, commonly, frequently, generally, now, widely, also,
# Nearest to the: their, its, this, any, a, these, some, witches,
# Nearest to by: through, in, be, riichi, pastors, retail, xx, mebyon,
# Average loss at step 72000: 3.374011
# Average loss at step 74000: 3.345603
# Average loss at step 76000: 3.306334
# Average loss at step 78000: 3.350686
# Average loss at step 80000: 3.375213
# Nearest to of: in, original, telepathy, categorised, kochi, kon, cereals, puzzling,
# Nearest to new: ainsworth, different, arbitration, enlai, medical, symbolist, anisotropies, compagnie,
# Nearest to this: which, it, another, itself, he, the, sac, loaf,
# Nearest to called: named, used, known, handball, referred, considered, entitled, advertise,
# Nearest to during: after, throughout, in, before, when, against, until, from,
# Nearest to is: was, has, are, seems, be, became, suborbital, becomes,
# Nearest to or: and, than, gratis, immunization, dion, kao, nasrallah, psychosomatic,
# Nearest to over: palestinian, before, between, around, about, normalized, dactyl, under,
# Nearest to four: six, five, three, seven, eight, two, nine, zero,
# Nearest to he: she, it, they, there, who, never, informatics, we,
# Nearest to not: still, generally, they, usually, now, actually, piero, also,
# Nearest to d: b, m, f, p, n, dc, guarantee, loud,
# Nearest to most: more, many, some, less, especially, several, highly, all,
# Nearest to often: sometimes, commonly, usually, frequently, generally, typically, now, also,
# Nearest to the: his, its, their, a, copa, this, your, her,
# Nearest to by: through, pastors, with, when, xx, scheldt, uralic, goose,
# Average loss at step 82000: 3.408325
# Average loss at step 84000: 3.410548
# Average loss at step 86000: 3.389364
# Average loss at step 88000: 3.350198
# Average loss at step 90000: 3.363033
# Nearest to of: for, in, including, keanu, following, during, bandleaders, margarine,
# Nearest to new: particular, different, ainsworth, enlai, utrecht, symbolist, oldsmobile, icing,
# Nearest to this: it, which, the, itself, what, he, sac, any,
# Nearest to called: named, used, known, referred, handball, considered, see, entitled,
# Nearest to during: after, throughout, in, before, until, when, from, at,
# Nearest to is: was, has, are, although, be, makes, takes, becomes,
# Nearest to or: and, immunization, including, than, bisexual, tiglath, unlucky, regulates,
# Nearest to over: within, palestinian, almost, about, demarcation, under, around, between,
# Nearest to four: seven, five, eight, six, three, two, nine, one,
# Nearest to he: she, it, they, there, who, informatics, later, we,
# Nearest to not: still, piero, generally, now, we, actually, grandsons, they,
# Nearest to d: b, caitlin, dc, m, moose, pylons, tombstone, guarantee,
# Nearest to most: many, more, less, some, arcadia, highly, especially, use,
# Nearest to often: sometimes, commonly, usually, frequently, generally, typically, now, also,
# Nearest to the: its, this, any, their, a, his, each, copa,
# Nearest to by: through, with, under, against, uralic, scheldt, during, when,
# Average loss at step 92000: 3.397985
# Average loss at step 94000: 3.250471
# Average loss at step 96000: 3.359487
# Average loss at step 98000: 3.237783
# Average loss at step 100000: 3.358015
# Nearest to of: including, and, in, ps, bandleaders, original, from, include,
# Nearest to new: different, symbolist, popular, chocolat, following, enlai, ainsworth, fitna,
# Nearest to this: it, which, what, sac, he, another, itself, that,
# Nearest to called: named, referred, used, known, handball, entitled, commandant, relatedness,
# Nearest to during: after, in, throughout, before, until, since, when, through,
# Nearest to is: was, has, are, became, seems, becomes, be, when,
# Nearest to or: and, than, tiglath, pioneering, diarist, comptroller, seperate, cimmerians,
# Nearest to over: xxxx, between, around, decins, palestinian, consecutive, about, almost,
# Nearest to four: six, seven, eight, five, three, two, nine, zero,
# Nearest to he: she, it, they, there, who, we, never, this,
# Nearest to not: piero, still, generally, never, actually, now, jellicoe, nor,
# Nearest to d: b, marina, c, ie, sarah, upsurge, dc, andersonville,
# Nearest to most: more, less, many, especially, particularly, some, highly, arcadia,
# Nearest to often: sometimes, commonly, usually, frequently, generally, typically, now, widely,
# Nearest to the: their, his, its, your, a, whose, bestows, some,
# Nearest to by: through, including, scheldt, mebyon, against, under, sorbian, when,

# %%
######################################
### CBOW (Continuous Bag of Words) ###
######################################
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
######################################
### CBOW (Continuous Bag of Words) ###
######################################
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                       ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
